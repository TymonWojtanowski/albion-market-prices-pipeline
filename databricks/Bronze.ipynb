# %% [markdown]
# #Reading from parquet file

# %%
df = spark.read.parquet(
    "/Volumes/albion_project/bronze/data/prices.parquet"
)

display(df)

# %% [markdown]
# #Write it to Bronze Layer

# %%
(
    df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("albion_project.bronze.prices")
)
